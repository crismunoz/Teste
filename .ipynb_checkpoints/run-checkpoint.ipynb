# %%
import matplotlib.pyplot as plt
from data import load_data
import numpy as np

bs = np.linspace(0, 0.25, 10)
gs = np.linspace(9.5, 9.89, 10)
hs = np.linspace(0.5, 0.10, 10)
n = 10

time = []
position = []
g_param = []
h_param = []
b_param = []
for g in gs:
    for h in hs:
        for b in bs:
            time_b, position_b, _ = load_data(g = g, h = h, b = b, n=n)
            time+=list(time_b)
            position+=list(position_b)
            g_param+=[g]*n
            h_param+=[h]*n
            b_param+=[b]*n
            
time = np.array(time)
position = np.array(position)
g_param = np.array(g_param)
h_param = np.array(h_param)
b_param = np.array(b_param)

# %%
plt.plot(time, position, 'orange', linewidth = 2)
plt.xlabel('time (s)')
plt.ylabel('position (cm)')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.grid(True)

# %%
from dataset import AdvDebDataset
from trainer import TrainArgs, Trainer
from model import AdversarialDebiasingModel
from torch.utils.data import DataLoader

hidden_size=128
keep_prob=0.1
device='cuda'
batch_size=2048
epochs=100
feature_dim =3

import numpy as np
time_np = time/np.max(time)
position_np = position/np.max(position)
h_param_np = h_param/np.max(h_param)
b_param_np = b_param/np.max(b_param)
g_param_np = g_param/np.max(g_param)
params_np = np.stack((h_param_np[:-1], b_param_np[:-1], g_param_np[:-1]), axis=1)
use_debias=False
train_args = TrainArgs(epochs=epochs)
traindataset = AdvDebDataset(time_np[:-1,], position_np[:-1], params_np, position_np[1:], device=device)
dataloader = DataLoader(traindataset, batch_size=batch_size, shuffle=True)
adm = AdversarialDebiasingModel(feature_dim, hidden_size, keep_prob).to(device)

# %%
trainer = Trainer(adm, dataloader, train_args, use_debias=use_debias)
running_loss = trainer.train()
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/home/cristian/.pyenv/versions/3.9.12/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#  11%|████▌                                     | 11/100 [01:05<08:50,  5.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 trainer = Trainer(adm, dataloader, train_args, use_debias=use_debias)
# ----> 2 running_loss = trainer.train()
#
# File /mnt/c/Users/Cristian/Teste/trainer.py:136, in Trainer.train(self)
#     134 running_loss = {"reg": [], "adv": []}
#     135 for ep in tqdm(range(self.train_args.epochs), total=self.train_args.epochs):
# --> 136   for i, data in enumerate(self.trainloader, 0):
#     138       loss_reg, loss_adv = (
#     139           self.train_step_with_debias(data)
#     140           if self.use_debias
#     141           else self.train_step(data)
#     142       )
#     144       running_loss["reg"].append(loss_reg.item())
#
# File ~/.pyenv/versions/3.9.12/lib/python3.9/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.pyenv/versions/3.9.12/lib/python3.9/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.pyenv/versions/3.9.12/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/.pyenv/versions/3.9.12/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File /mnt/c/Users/Cristian/Teste/dataset.py:27, in AdvDebDataset.__getitem__(self, idx)
#      25 x0 = torch.tensor(self.x0[idx]).type(torch.FloatTensor).to(self.device)
#      26 y = torch.tensor(self.y[idx, None]).type(torch.FloatTensor).to(self.device)
# ---> 27 params = torch.tensor(self.params[idx]).type(torch.FloatTensor).to(self.device)
#      28 neg_exp = torch.tensor([0]).type(torch.FloatTensor).to(self.device)+EPS
#      29 pos_exp = torch.tensor([1]).type(torch.FloatTensor).to(self.device)-EPS
#
# KeyboardInterrupt:

# %%
use_debias=True
running_losses_debias = []
trainers_debias = []
ad_los_ws = [0.001, 0.01, 0.02]
for adversary_loss_weight in ad_los_ws:
    train_args = TrainArgs(epochs=epochs, adversary_loss_weight=adversary_loss_weight)
    traindataset = AdvDebDataset(time_np[:-1,], position_np[:-1], params_np, position_np[1:],  device=device)
    dataloader = DataLoader(traindataset, batch_size=batch_size, shuffle=True)
    adm = AdversarialDebiasingModel(feature_dim, hidden_size, keep_prob).to(device)
    trainer_debias = Trainer(adm, dataloader, train_args, use_debias=use_debias)
    trainers_debias.append(trainer_debias)
    running_loss_debias = trainer_debias.train()
    running_losses_debias.append(running_loss_debias)

# %%
plt.figure(figsize=(20,5))
plt.plot(running_loss['reg'])
legends = ['org']
for i,running_loss_debias in enumerate(running_losses_debias):
    plt.plot(running_loss_debias['reg'])
    legends.append(f'debias-{ad_los_ws[i]}')
    
plt.legend(legends)
#plt.ylim([0,0.002])
#plt.xlim([0,100])
plt.grid()

# %%
plt.figure(figsize=(20,5))
for i,running_loss_debias in enumerate(running_losses_debias):
    plt.plot(running_loss_debias['adv'])
plt.grid()

# %%
import torch
t = time_np[:-1,]
p = position_np[:-1]

data_len = len(t)
t = torch.Tensor(t.reshape([data_len,1])).type(torch.FloatTensor).to(device)
p = torch.Tensor(p.reshape([data_len, -1])).type(torch.FloatTensor).to(device)
params = torch.Tensor(params_np.reshape([data_len, -1])).type(torch.FloatTensor).to(device)

pred_position = trainer.adverarial_debiasing_model.regressor(t,p).detach().numpy()

pred_positions_debias = []
for trainer_debias in trainers_debias:
    pred_position_debias = trainer_debias.adverarial_debiasing_model.regressor(t, p, params).detach().numpy()
    pred_positions_debias.append(pred_position_debias)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))
#plt.figure()
plt.plot(position_np.reshape(-1))
plt.plot(pred_position.reshape(-1))
legends = ['original', 'no debias']
for i,pred_position_debias in enumerate(pred_positions_debias):
    plt.plot(pred_position_debias.reshape(-1))
    legends.append(f'debias-{ad_los_ws[i]}')
plt.legend(legends)
plt.grid()
plt.show()
